# %%
DIR_PATH = '../../data/6_11_2025'

# %%
import os

if os.path.exists(DIR_PATH):
    print(f"The directory '{DIR_PATH}' exists.")
else:
    print(f"The directory '{DIR_PATH}' does not exist.")
# Out:
# The directory '../../data/6_11_2025' exists.

# %%
import os

def process_inside_paths(dir):
    return os.path.join(DIR_PATH, dir)

# %%
def get_file_types(dirs):
    files_types = dict()

    for dir in dirs:
        files = [file for file in os.listdir(dir) if os.path.isfile(os.path.join(dir, file))]
        types = set(f[:3] for f in files)

        for type in types:
            mp3s = {file[:-4] for file in files if file[-4:] == '.mp3' and file.startswith(type)}
            textGrids = {file[:-9] for file in files if file[-9:] == '.TextGrid' and file.startswith(type)}
            pairs = len(mp3s.intersection(textGrids))
            
            if type in files_types.keys():
                files_types[type] += pairs
            else:
                files_types[type] = pairs    
    
    return files_types

# %%
import matplotlib.pyplot as plt

all_items = os.listdir(DIR_PATH)
directories = [process_inside_paths(item) for item in all_items if os.path.isdir(os.path.join(DIR_PATH, item))]

types = get_file_types(directories)

plt.bar(types.keys(), types.values())
plt.xlabel('File type')
plt.ylabel('Number of files')
plt.title('Number of files per type')
plt.show()
print('types:', types)
# Out:
# types: {'tcc': 267, '201': 112, 'IGS': 10}

# %%
import tgt
import textgrid

def get_textgrid_duration_tgt(path):
    try:
        grid = tgt.read_textgrid(path)
        return 200, grid.end_time
    except Exception as e:
        print(f"An unexpected error occurred: {e} in {path}")
        return 400, 0.0

def get_textgrid_duration_textgrid(path):
    try:
        tg = textgrid.TextGrid.fromFile(path)
        return 200, tg.maxTime
    except Exception as e:
        print(f"[textgrid WARN] {path}: {e}")
        return 400, 0.0
        
def get_summed_durations(dirs, types, type):
    durations = dict.fromkeys(types, 0)
    errors = 0
    for dir in dirs:
        files = [file for file in os.listdir(dir) if os.path.isfile(os.path.join(dir, file))]
        mp3s = {file[:-4] for file in files if file[-4:] == '.mp3'}
        textGrids = {file[:-9] for file in files if file[-9:] == '.TextGrid'}
        pairs = mp3s.intersection(textGrids)

        for file in pairs:
            file_path = os.path.join(dir, file + '.TextGrid')
            if type == 'tgt':
                code, duration = get_textgrid_duration_tgt(file_path)
            else:
                code, duration = get_textgrid_duration_textgrid(file_path)
                
            if code == 200:
                durations[file[:3]] += duration
            else:
                errors += 1

    return durations, errors

# %%
durations, errors = get_summed_durations(directories, types, 'tgt')
print('ERRORS', errors)

plt.bar(durations.keys(), durations.values())
plt.xlabel('File type')
plt.ylabel('Summed durations')
plt.title('Summed durations per type (tgt approved)')
plt.show()
print('types:', types)
# Out:
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Tonal case 9/tcc_dato1239_tsim1256_IGS0229_2016-2-28_GG2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Verbal inflections and tonal case 2/tcc_dato1239_tsim1256_IGS0229_2016-2-2_GG2_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Verb root categories/tcc_dato1239_tsim1256_IGS0229_2015-12-30_GG2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Phonology and verbs/tcc_dato1239_tsim1256_IGS0229_2015-12-23_YN.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Tonal case 1/tcc_dato1239_tsim1256_IGS0229_2016-2-17_YM_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for physical actions 1/2015-5-27_IGS0229_RG_EB_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for manipulating objects 1/2015-5-31_IGS0229_RG_EB_Session_2_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Dictionary words 5/tcc_dato1239_tsim1256_IGS0229_2016-1-17_GG2_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Dictionary words 2/tcc_dato1239_tsim1256_IGS0229_2016-1-12_GG2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Review of various lexical items/2015-6-1_IGS0229_RG_YM_Session_3_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Review of various lexical items/2015-6-1_IGS0229_RG_YM_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Body part terminology 4/2015-5-17_IGS0229_RG_EB_Session_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Verb paradigms 9/2015-6-1_IGS0229_RG_YM_Session_3_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Verb paradigms 9/2015-6-1_IGS0229_RG_YM_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Body part terminology 3/2015-5-17_IGS0229_RG_EB_Session_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Animal and plant names 1/2015-5-25_IGS0229_RG_KM_Session_2_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Word order and tonal case 2/tcc_dato1239_tsim1256_IGS0229_2016-2-16_GG2_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Word order and tonal case 2/tcc_dato1239_tsim1256_IGS0229_2016-2-16_GG2_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for physical states and illnesses/2015-5-27_IGS0229_RG_EB_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Traditional education/tcc_dato1239_tsim1256_IGS0229_2015-12-27_MB_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Traditional education/tcc_dato1239_tsim1256_IGS0229_2015-12-27_MB_3.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Names for different type of people 2/2015-5-18_IGS0229_RG_YM_Session_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Natural objects 2/2015-5-25_IGS0229_RG_BD_Session_1_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Natural objects 2/2015-5-25_IGS0229_RG_BD_Session_2_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for music, dance, and games/2015-6-1_IGS0229_RG_YM_Session_3_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for music, dance, and games/2015-6-1_IGS0229_RG_YM_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for cooking tools/2015-5-25_IGS0229_RG_BD_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for cooking tools/2015-5-25_IGS0229_RG_BD_Session_2_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Traditional life/tcc_dato1239_tsim1256_IGS0229_2015-12-27_MB_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Traditional life/tcc_dato1239_tsim1256_IGS0229_2015-12-27_MB_3.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Verbal inflections and tonal case 1/tcc_dato1239_tsim1256_IGS0229_2016-2-2_GG2_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Tonal case 3/tcc_dato1239_tsim1256_IGS0229_2016-2-17_YM_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Tonal case 4/tcc_dato1239_tsim1256_IGS0229_2016-2-17_YN_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Tonal case 4/tcc_dato1239_tsim1256_IGS0229_2016-2-17_YN_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Animal names 3x/2015-5-21_IGS0229_RG_YM_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for tools and harvesting/2015-5-31_IGS0229_RG_EB_Session_2_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Tonal case 5/tcc_dato1239_tsim1256_IGS0229_2016-2-17_YN_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Tonal case 5/tcc_dato1239_tsim1256_IGS0229_2016-2-17_YN_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Traditional dances and marriage/IGS0229_2017-1-25_MM_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Tonal case 2/tcc_dato1239_tsim1256_IGS0229_2016-2-17_YM_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Kinship terminology/2015-5-18_IGS0229_RG_YM_Session_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Datooga groups 2/tcc_dato1239_tsim1256_IGS0229_2015-12-27_MB_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Datooga groups 2/tcc_dato1239_tsim1256_IGS0229_2015-12-27_MB_3.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Word order and tonal case 1/tcc_dato1239_tsim1256_IGS0229_2016-2-16_GG2_1.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Word order and tonal case 1/tcc_dato1239_tsim1256_IGS0229_2016-2-16_GG2_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Verb paradigms and short verb phrases/tcc_dato1239_tsim1256_IGS0229_2016-1-17_GG2_2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Animal names 2/2015-5-21_IGS0229_RG_YM_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Animal and plant names 2/2015-5-25_IGS0229_RG_KM_Session_2_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Possession, ditransitives, and applicatives/tcc_dato1239_tsim1256_IGS0229_2016-1-19_MB2.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for home items and structures/2015-5-25_IGS0229_RG_BD_Session_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for home items and structures/2015-5-25_IGS0229_RG_BD_Session_2_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Imperative verbs/tcc_dato1239_tsim1256_IGS0229_2015-12-9_YN.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Natural objects 1/2015-5-25_IGS0229_RG_BD_Session_1_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Natural objects 1/2015-5-25_IGS0229_RG_BD_Session_2_1_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for traveling and carrying loads/2015-6-1_IGS0229_RG_YM_Session_3_.TextGrid
# An unexpected error occurred: list index out of range in ../../data/6_11_2025/Words for traveling and carrying loads/2015-6-1_IGS0229_RG_YM_Session_1_.TextGrid
# ERRORS 56
# types: {'tcc': 267, '201': 112, 'IGS': 10}

# %%
durations, errors = get_summed_durations(directories, types, 'textgrid')
print('ERRORS', errors)

plt.bar(durations.keys(), durations.values())
plt.xlabel('File type')
plt.ylabel('Summed durations')
plt.title('Summed durations per type (textgrid)')
plt.show()
# Out:
# ERRORS 0

# %%
import textgrid

def get_tiers(path):
    try:
        tg = textgrid.TextGrid.fromFile(path)
        tier_names = [tier.name for tier in tg.tiers]
        return 200, tier_names
    except Exception as e:
        print(f"[textgrid WARN] {path}: {e}")
        return 400, 0.0
        
def get_tier_names(dirs, types):
    tier_names_by_type = {t: set() for t in types}
    errors = 0
    for dir in dirs:
        files = [file for file in os.listdir(dir) if os.path.isfile(os.path.join(dir, file))]
        mp3s = {file[:-4] for file in files if file[-4:] == '.mp3'}
        textGrids = {file[:-9] for file in files if file[-9:] == '.TextGrid'}
        pairs = mp3s.intersection(textGrids)

        for file in pairs:
            file_path = os.path.join(dir, file + '.TextGrid')
 
            code, tiers = get_tiers(file_path)
                
            if code == 200:
                tier_names_by_type[file[:3]].update(tiers)
            else:
                errors += 1
    
    return tier_names_by_type, errors

# %%
tiers_dict, errors = get_tier_names(directories, types)
print(tiers_dict)
for type, tiers in tiers_dict.items():
    print('TYPE: ', type)
    print('unique tiers:', tiers)
# Out:
# {'tcc': {'IPA', 'Swahili', 'English', 'Asmjeeg'}, '201': {'ref@RM', 'ref@KM', 'ref@YM', 'ref', 'ref@BD', 'ref@EB'}, 'IGS': {'FT-ENG', 'REF', 'Transcription', 'FT-SWA'}}
# TYPE:  tcc
# unique tiers: {'IPA', 'Swahili', 'English', 'Asmjeeg'}
# TYPE:  201
# unique tiers: {'ref@RM', 'ref@KM', 'ref@YM', 'ref', 'ref@BD', 'ref@EB'}
# TYPE:  IGS
# unique tiers: {'FT-ENG', 'REF', 'Transcription', 'FT-SWA'}

# %%
import re

transcription_tiers_map = {
    "tcc": r"^Asmjeeg$",
    "201": r"^ref",
    "IGD": r"Transcription"
}

def get_tiers_duration(path, file_type):
    tier_name = transcription_tiers_map[file_type]

    try:
        tg = textgrid.TextGrid.fromFile(path)
        duration = 0
        for tier in tg.tiers:
            if not re.search(tier_name, tier.name, re.IGNORECASE):
                continue
            
            if isinstance(tier, textgrid.IntervalTier):
                for interval in tier:
                    if interval.mark.strip():
                        print(interval.mark.strip(), interval.maxTime - interval.minTime)
                        duration += (interval.maxTime - interval.minTime)   

        return 200, duration
    except Exception as e:
        print(f"[textgrid WARN] {path}: {e}")
        return 400, 0.0

def get_non_silent_durations(dirs, types):
    durations = dict.fromkeys(types, 0)
    errors = 0
    for dir in dirs:
        files = [file for file in os.listdir(dir) if os.path.isfile(os.path.join(dir, file))]
        mp3s = {file[:-4] for file in files if file[-4:] == '.mp3'}
        textGrids = {file[:-9] for file in files if file[-9:] == '.TextGrid'}
        pairs = mp3s.intersection(textGrids)

        for file in pairs:
            file_path = os.path.join(dir, file + '.TextGrid')
            code, duration = get_tiers_duration(file_path, file[:3])
                
            if code == 200:
                durations[file[:3]] += duration
            else:
                errors += 1

    return durations, errors

# %%
durations, errors = get_non_silent_durations(directories, types)
print('ERRORS', errors)

plt.bar(durations.keys(), durations.values())
plt.xlabel('File type')
plt.ylabel('Summed non-silent durations')
plt.title('Summed durations per type (textgrid)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 durations, errors = get_non_silent_durations(directories, types)
#       2 print('ERRORS', errors)
#       4 plt.bar(durations.keys(), durations.values())
#
# Cell In[31], line 41, in get_non_silent_durations(dirs, types)
#      39 for file in pairs:
#      40     file_path = os.path.join(dir, file + '.TextGrid')
# ---> 41     code, duration = get_tiers_duration(file_path)
#      43     if code == 200:
#      44         durations[file[:3]] += duration
#
# TypeError: get_tiers_duration() missing 1 required positional argument: 'file_type'
